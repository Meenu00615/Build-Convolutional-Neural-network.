# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
import numpy as np

# %%
batch_size = 128
num_classes = 10
epochs = 12

# %%
# input image dimensions
img_rows, img_cols = 28, 28
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000,28,28,1)
x_test = x_test.reshape(10000,28,28,1)
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
activation='relu',
input_shape=(28,28,1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss=keras.losses.categorical_crossentropy,
optimizer=keras.optimizers.Adadelta(),
metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
batch_size=batch_size,
epochs=epochs,
verbose=1,
validation_data=(x_test, y_test))
# Out:
# Epoch 1/12
# 469/469 [==============================] - 161s 341ms/step - loss: 25.8763 - accuracy: 0.1617 - val_loss: 4.1966 - val_accuracy: 0.4301
# Epoch 2/12
# 469/469 [==============================] - 147s 314ms/step - loss: 11.0705 - accuracy: 0.2634 - val_loss: 1.7244 - val_accuracy: 0.5922
# Epoch 3/12
# 469/469 [==============================] - 145s 309ms/step - loss: 5.8765 - accuracy: 0.3348 - val_loss: 1.2004 - val_accuracy: 0.6205
# Epoch 4/12
# 469/469 [==============================] - 147s 315ms/step - loss: 3.6273 - accuracy: 0.3625 - val_loss: 1.2694 - val_accuracy: 0.5957
# Epoch 5/12
# 469/469 [==============================] - 145s 310ms/step - loss: 2.6626 - accuracy: 0.3648 - val_loss: 1.4259 - val_accuracy: 0.5567
# Epoch 6/12
# 469/469 [==============================] - 146s 311ms/step - loss: 2.2200 - accuracy: 0.3775 - val_loss: 1.4727 - val_accuracy: 0.5508
# Epoch 7/12
# 469/469 [==============================] - 145s 308ms/step - loss: 2.0325 - accuracy: 0.3894 - val_loss: 1.4384 - val_accuracy: 0.5718
# Epoch 8/12
# 469/469 [==============================] - 146s 311ms/step - loss: 1.9170 - accuracy: 0.4081 - val_loss: 1.3810 - val_accuracy: 0.5937
# Epoch 9/12
# 469/469 [==============================] - 149s 318ms/step - loss: 1.8340 - accuracy: 0.4299 - val_loss: 1.3034 - val_accuracy: 0.6282
# Epoch 10/12
# 469/469 [==============================] - 151s 322ms/step - loss: 1.7500 - accuracy: 0.4591 - val_loss: 1.2209 - val_accuracy: 0.6511
# Epoch 11/12
# 469/469 [==============================] - 145s 309ms/step - loss: 1.6893 - accuracy: 0.4757 - val_loss: 1.1626 - val_accuracy: 0.6700
# Epoch 12/12
# 469/469 [==============================] - 145s 308ms/step - loss: 1.6377 - accuracy: 0.4919 - val_loss: 1.1102 - val_accuracy: 0.6875

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 1.1101772785186768
# Test accuracy: 0.6875
